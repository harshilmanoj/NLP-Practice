# %% [markdown]
# **POS tagging for "shakespeare-caesar.txt” from Gutenberg Corpus**

# %% [markdown]
# **Method : Averaged_perceptron_tagger**

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import gutenberg
nltk.download('averaged_perceptron_tagger')
nltk.download('gutenberg')
gwords = set(gutenberg.words("shakespeare-caesar.txt"))
nltk.pos_tag(gwords)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [('Mur', 'NNP'),
#  ('Worthinesse', 'NNP'),
#  ('Rubbish', 'NNP'),
#  ('home', 'NN'),
#  ('mighty', 'NN'),
#  ('hence', 'NN'),
#  ('Remember', 'NNP'),
#  ('lodge', 'NN'),
#  ('sate', 'NN'),
#  ('whet', 'NN'),
#  ('Yea', 'NNP'),
#  ('beat', 'NN'),
#  ('sham', 'JJ'),
#  ('Predictions', 'NNP'),
#  ('Mistrust', 'NNP'),
#  ('kill', 'VB'),
#  ('stabb', 'JJ'),
#  ('Miseries', 'NNS'),
#  ('sorrow', 'VBP'),
#  ('hundred', 'VBN'),
#  ('sit', 'NN'),
#  ('Plucking', 'VBG'),
#  ('offended', 'VBD'),
#  ('poor', 'JJ'),
#  ('Vol', 'NNP'),
#  ('sowre', 'NN'),
# ...

# %% [markdown]
# **Using the Tagged Corpus to find the conditional probability distribution of words.**

# %% [markdown]
# **Probability of an adverb being ‘not’ and a determinant being ‘the’:**

# %%
gutenberg_tagged_sents = [nltk.pos_tag(gwords)]
gutenberg_word_tags=[]
for gutenberg_sent in gutenberg_tagged_sents:
    gutenberg_word_tags.append(('START','START'))
    for words,tag in gutenberg_sent:
      gutenberg_word_tags.extend([(tag[:2],words)])
    gutenberg_word_tags.append(('END','END'))


cfd1_tag_words_guten=nltk.ConditionalFreqDist(gutenberg_word_tags)
cpd_tag_words_guten=nltk.ConditionalProbDist(cfd1_tag_words_guten,nltk.MLEProbDist)


print("The probability of an adverb (RB) being 'not' is", cpd_tag_words_guten["RB"].prob("not"))
print("The probability of a determinant (DT) being 'the' is", cpd_tag_words_guten["DT"].prob("the"))
# Out:
# The probability of an adverb (RB) being 'not' is 0.007751937984496124
# The probability of a determinant (DT) being 'the' is 0.043478260869565216

# %% [markdown]
# **Probability of DT occurring after NN and VB occurring after NN:**

# %%
guten_tags=[]
for tag, words in gutenberg_word_tags:
    guten_tags.append(tag)

cfd_tags_gutenberg=nltk.ConditionalFreqDist(nltk.bigrams(guten_tags))
cpd_tag_gutenberg=nltk.ConditionalProbDist(cfd_tags_gutenberg,nltk.MLEProbDist)

print('The probability of DT occuring after NN is : ', cpd_tag_gutenberg["NN"].prob("DT"))
print('The probability of VB occuring after NN is : ', cpd_tag_gutenberg["NN"].prob("VB"))
# Out:
# The probability of DT occuring after NN is :  0.004420866489832007
# The probability of VB occuring after NN is :  0.1962864721485411

# %% [markdown]
# **CLASS ACTIVITY**

# %% [markdown]
# **Tagging (Averaged_perceptron_tagger)**

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize , sent_tokenize
text = word_tokenize("killer crazy down problem")
nltk.pos_tag(text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('killer', 'NN'), ('crazy', 'VBP'), ('down', 'RP'), ('problem', 'NN')]

# %% [markdown]
# **Tagging (Text from file)**

# %%
from google.colab import files
a = files.upload()
# Out:
#      <input type="file" id="files-bccd5ee5-5a5f-4ca2-9604-096fdb322b2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bccd5ee5-5a5f-4ca2-9604-096fdb322b2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from nltk.corpus.reader import wordlist
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words("english"))
f = open("test1.txt","r")
txt = f.read()


tokenized_txt = sent_tokenize(txt)
for i in tokenized_txt:
  wordlist = word_tokenize(i)
  wordlist = [w for w in wordlist if not w in stop_words]
tagged = nltk.pos_tag(wordlist)
print(tagged)
# Out:
# [('I', 'PRP'), ('third', 'VBP'), ('year', 'NN'), ('Computer', 'NNP'), ('Science', 'NNP'), ('Engineering', 'NNP'), ('student', 'NN'), ('.', '.')]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Tagging (Brown Corpus)**

# %%
from nltk.corpus import brown
nltk.download('brown')
tag_sentences =  brown.tagged_sents(categories='news')
print(tag_sentences[15])
# Out:
# [('The', 'AT'), ('jurors', 'NNS'), ('said', 'VBD'), ('they', 'PPSS'), ('realize', 'VB'), ('``', '``'), ('a', 'AT'), ('proportionate', 'JJ'), ('distribution', 'NN'), ('of', 'IN'), ('these', 'DTS'), ('funds', 'NNS'), ('might', 'MD'), ('disable', 'VB'), ('this', 'DT'), ('program', 'NN'), ('in', 'IN'), ('our', 'PP$'), ('less', 'QL'), ('populous', 'JJ'), ('counties', 'NNS'), ("''", "''"), ('.', '.')]
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %% [markdown]
# **Tagging (Universal_tagset)**

# %%
nltk.download('universal_tagset')
txt1 = "This is a sample text"
token = word_tokenize(txt1)
tag = nltk.pos_tag(token,tagset="universal")
print(tag)
# Out:
# [('This', 'DET'), ('is', 'VERB'), ('a', 'DET'), ('sample', 'ADJ'), ('text', 'NOUN')]
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.

# %% [markdown]
# **Tagging (Tree Bank)**

# %%
from nltk.corpus import treebank
nltk.download('treebank')
traindata = treebank.tagged_sents()[:3000]
print(traindata)
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [[('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('will', 'MD'), ('join', 'VB'), ('the', 'DT'), ('board', 'NN'), ('as', 'IN'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')], [('Mr.', 'NNP'), ('Vinken', 'NNP'), ('is', 'VBZ'), ('chairman', 'NN'), ('of', 'IN'), ('Elsevier', 'NNP'), ('N.V.', 'NNP'), (',', ','), ('the', 'DT'), ('Dutch', 'NNP'), ('publishing', 'VBG'), ('group', 'NN'), ('.', '.')], ...]

# %% [markdown]
# **Tagging (Using HiddenMarkovModelTagger)**

# %%
from nltk.tag import hmm
tagger = nltk.HiddenMarkovModelTagger.train(traindata)
print(tagger)
# Out:
# <HiddenMarkovModelTagger 46 states and 10779 output symbols>

# %%
print(tagger.tag("Today is a good day to learn".split()))
# Out:
# [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('good', 'JJ'), ('day', 'NN'), ('to', 'TO'), ('learn', 'VB')]

# %% [markdown]
# **Probability of an adjective being ‘smart’ and a verb being ‘try’:**

# %%
from nltk.corpus import brown
brown.tagged_sents()
brown_word_tags=[]
for brown_sent in brown.tagged_sents():
    brown_word_tags.append(('START','START'))
    for words,tag in brown_sent:
      brown_word_tags.extend([(tag[:2],words)])
    brown_word_tags.append(('END','END'))

cfd_tag_words=nltk.ConditionalFreqDist(brown_word_tags)
cpd_tag_words=nltk.ConditionalProbDist(cfd_tag_words,nltk.MLEProbDist)
print("The probability of an adjective (JJ) being 'smart' is", cpd_tag_words["JJ"].prob("smart"))
print("The probability of a verb (VB) being 'try' is", cpd_tag_words["VB"].prob("try"))
# Out:
# The probability of an adjective (JJ) being 'smart' is 0.00027780092785509904
# The probability of a verb (VB) being 'try' is 0.0010790559555256297

# %% [markdown]
# **Probability of DT occurring after NN and VB occurring after NN:**

# %%
brown_tags=[]
for tag, words in brown_word_tags:
    brown_tags.append(tag)
cfd_tags=nltk.ConditionalFreqDist(nltk.bigrams(brown_tags))
cpd_tags=nltk.ConditionalProbDist(cfd_tags,nltk.MLEProbDist)
print('The probability of DT occuring after NN is : ', cpd_tags["NN"].prob("DT"))
print('The probability of VB occuring after NN is : ', cpd_tags["NN"].prob("VB"))
# Out:
# The probability of DT occuring after NN is :  0.0018349509874933604
# The probability of VB occuring after NN is :  0.0646359290427087
