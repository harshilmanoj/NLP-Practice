# %%
import nltk

# %%
from nltk.corpus import wordnet as wn
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
wn.synsets('motorcar')
# Out:
# [Synset('car.n.01')]

# %%
wn.synset('car.n.01').lemma_names()
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']

# %%
wn.synset('car.n.02').lemma_names()
# Out:
# ['car', 'railcar', 'railway_car', 'railroad_car']

# %%
wn.synset('car.n.00').lemma_names()
# Out:
# ['cable_car', 'car']

# %%
wn.synset('car.n.01').definition()
# Out:
# 'a motor vehicle with four wheels; usually propelled by an internal combustion engine'

# %%
wn.synset('car.n.02').definition()
# Out:
# 'a wheeled vehicle adapted to the rails of railroad'

# %%
wn.synset('car.n.01').examples()
# Out:
# ['he needs a car to get to work']

# %%
wn.synset('car.n.02').examples()
# Out:
# ['three cars had jumped the rails']

# %%
wn.synset('car.n.01').lemmas()
# Out:
# [Lemma('car.n.01.car'),
#  Lemma('car.n.01.auto'),
#  Lemma('car.n.01.automobile'),
#  Lemma('car.n.01.machine'),
#  Lemma('car.n.01.motorcar')]

# %%
wn.synset('car.n.02').lemmas()
# Out:
# [Lemma('car.n.02.car'),
#  Lemma('car.n.02.railcar'),
#  Lemma('car.n.02.railway_car'),
#  Lemma('car.n.02.railroad_car')]

# %%
wn.lemma('car.n.02.railcar').synset().name()
# Out:
# 'car.n.02'

# %%
for syn in wn.synsets('car'):
  print(syn.lemma_names())
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']
# ['car', 'railcar', 'railway_car', 'railroad_car']
# ['car', 'gondola']
# ['car', 'elevator_car']
# ['cable_car', 'car']

# %%
wn.synsets('book',wn.VERB)
# Out:
# [Synset('book.v.01'),
#  Synset('reserve.v.04'),
#  Synset('book.v.03'),
#  Synset('book.v.04')]

# %%
wn.synset('car.n.01').hyponyms()
# Out:
# [Synset('ambulance.n.01'),
#  Synset('beach_wagon.n.01'),
#  Synset('bus.n.04'),
#  Synset('cab.n.03'),
#  Synset('compact.n.03'),
#  Synset('convertible.n.01'),
#  Synset('coupe.n.01'),
#  Synset('cruiser.n.01'),
#  Synset('electric.n.01'),
#  Synset('gas_guzzler.n.01'),
#  Synset('hardtop.n.01'),
#  Synset('hatchback.n.01'),
#  Synset('horseless_carriage.n.01'),
#  Synset('hot_rod.n.01'),
#  Synset('jeep.n.01'),
#  Synset('limousine.n.01'),
#  Synset('loaner.n.02'),
#  Synset('minicar.n.01'),
#  Synset('minivan.n.01'),
#  Synset('model_t.n.01'),
#  Synset('pace_car.n.01'),
#  Synset('racer.n.02'),
#  Synset('roadster.n.01'),
#  Synset('sedan.n.01'),
#  Synset('sport_utility.n.01'),
#  Synset('sports_car.n.01'),
#  Synset('stanley_steamer.n.01'),
#  Synset('stock_car.n.01'),
#  Synset('subcompact.n.01'),
#  Synset('touring_car.n.01'),
#  Synset('used-car.n.01')]

# %%
wn.synset('eclipse.n.01').hyponyms()
# Out:
# [Synset('lunar_eclipse.n.01'),
#  Synset('partial_eclipse.n.01'),
#  Synset('solar_eclipse.n.01'),
#  Synset('total_eclipse.n.01')]

# %%
wn.synset('car.n.01').hyponyms()
# Out:
# [Synset('ambulance.n.01'),
#  Synset('beach_wagon.n.01'),
#  Synset('bus.n.04'),
#  Synset('cab.n.03'),
#  Synset('compact.n.03'),
#  Synset('convertible.n.01'),
#  Synset('coupe.n.01'),
#  Synset('cruiser.n.01'),
#  Synset('electric.n.01'),
#  Synset('gas_guzzler.n.01'),
#  Synset('hardtop.n.01'),
#  Synset('hatchback.n.01'),
#  Synset('horseless_carriage.n.01'),
#  Synset('hot_rod.n.01'),
#  Synset('jeep.n.01'),
#  Synset('limousine.n.01'),
#  Synset('loaner.n.02'),
#  Synset('minicar.n.01'),
#  Synset('minivan.n.01'),
#  Synset('model_t.n.01'),
#  Synset('pace_car.n.01'),
#  Synset('racer.n.02'),
#  Synset('roadster.n.01'),
#  Synset('sedan.n.01'),
#  Synset('sport_utility.n.01'),
#  Synset('sports_car.n.01'),
#  Synset('stanley_steamer.n.01'),
#  Synset('stock_car.n.01'),
#  Synset('subcompact.n.01'),
#  Synset('touring_car.n.01'),
#  Synset('used-car.n.01')]

# %%
wn.synsets('tree')
# Out:
# [Synset('tree.n.01'),
#  Synset('tree.n.02'),
#  Synset('tree.n.03'),
#  Synset('corner.v.02'),
#  Synset('tree.v.02'),
#  Synset('tree.v.03'),
#  Synset('tree.v.04')]

# %%
wn.synset('tree.n.01').substance_meronyms()
# Out:
# [Synset('heartwood.n.01'), Synset('sapwood.n.01')]

# %%
wn.synset('tree.n.01').member_holonyms()
# Out:
# [Synset('forest.n.01')]

# %%
wn.synsets('wheel')
# Out:
# [Synset('wheel.n.01'),
#  Synset('steering_wheel.n.01'),
#  Synset('wheel.n.03'),
#  Synset('wheel.n.04'),
#  Synset('roulette_wheel.n.01'),
#  Synset('rack.n.04'),
#  Synset('bicycle.n.01'),
#  Synset('wheel.v.01'),
#  Synset('wheel.v.02'),
#  Synset('wheel.v.03'),
#  Synset('bicycle.v.01')]

# %%
wn.synset('wheel.n.01').definition()
# Out:
# 'a simple machine consisting of a circular frame with spokes (or a solid disc) that can rotate on a shaft or axle (as in vehicles or other machines)'

# %%
wn.synset('wheel.n.01').part_meronyms()
# Out:
# [Synset('felloe.n.01'), Synset('rim.n.03')]

# %%
wn.synset('wheel.n.01').part_holonyms()
# Out:
# [Synset('wheeled_vehicle.n.01')]

# %%
wn.synsets('walk')
# Out:
# [Synset('walk.n.01'),
#  Synset('base_on_balls.n.01'),
#  Synset('walk.n.03'),
#  Synset('walk.n.04'),
#  Synset('walk.n.05'),
#  Synset('walk.n.06'),
#  Synset('walk_of_life.n.01'),
#  Synset('walk.v.01'),
#  Synset('walk.v.02'),
#  Synset('walk.v.03'),
#  Synset('walk.v.04'),
#  Synset('walk.v.05'),
#  Synset('walk.v.06'),
#  Synset('walk.v.07'),
#  Synset('walk.v.08'),
#  Synset('walk.v.09'),
#  Synset('walk.v.10')]

# %%
wn.synset('walk.v.01').entailments()
# Out:
# [Synset('step.v.01')]

# %%
wn.synsets('supply')
# Out:
# [Synset('supply.n.01'),
#  Synset('supply.n.02'),
#  Synset('provision.n.02'),
#  Synset('supply.v.01'),
#  Synset('issue.v.02'),
#  Synset('provide.v.02'),
#  Synset('add.v.02')]

# %%
wn.synset('supply.n.02').lemmas()
# Out:
# [Lemma('supply.n.02.supply')]

# %%
wn.synset('supply.n.02').lemmas()[0].antonyms()
# Out:
# [Lemma('demand.n.02.demand')]

# %%
wn.synsets('rush')
# Out:
# [Synset('haste.n.02'),
#  Synset('rush.n.02'),
#  Synset('rush.n.03'),
#  Synset('rush.n.04'),
#  Synset('bang.n.04'),
#  Synset('rush.n.06'),
#  Synset('rush.n.07'),
#  Synset('rush.v.01'),
#  Synset('rush.v.02'),
#  Synset('rush.v.03'),
#  Synset('rush.v.04'),
#  Synset('rush.v.05'),
#  Synset('race.v.04'),
#  Synset('induce.v.03'),
#  Synset('first-come-first-serve.s.01'),
#  Synset('rush.s.02')]

# %%
wn.synset('rush.n.02').lemmas()
# Out:
# [Lemma('rush.n.02.rush'),
#  Lemma('rush.n.02.spate'),
#  Lemma('rush.n.02.surge'),
#  Lemma('rush.n.02.upsurge')]

# %%
wn.synset('rush.n.02').lemmas()[1].antonyms()
# Out:
# []

# %%
wn.synsets('ship')
# Out:
# [Synset('ship.n.01'),
#  Synset('transport.v.04'),
#  Synset('ship.v.02'),
#  Synset('embark.v.01'),
#  Synset('ship.v.04'),
#  Synset('ship.v.05')]

# %%
wn.synsets('cat')
# Out:
# [Synset('cat.n.01'),
#  Synset('guy.n.01'),
#  Synset('cat.n.03'),
#  Synset('kat.n.01'),
#  Synset('cat-o'-nine-tails.n.01'),
#  Synset('caterpillar.n.02'),
#  Synset('big_cat.n.01'),
#  Synset('computerized_tomography.n.01'),
#  Synset('cat.v.01'),
#  Synset('vomit.v.01')]

# %%
w1 = wn.synset('ship.n.01')
w2 = wn.synset('cat.n.01')
w1.wup_similarity(w2)
# Out:
# 0.6956521739130435

# %%
wn.synsets('dolphin')
# Out:
# [Synset('dolphinfish.n.02'), Synset('dolphin.n.02')]

# %%
wn.synsets('white_whale')
# Out:
# [Synset('white_whale.n.01')]

# %%
w3 = wn.synset('dolphinfish.n.02')
w4 = wn.synset('white_whale.n.01')
w3.lowest_common_hypernyms(w4)
# Out:
# [Synset('vertebrate.n.01')]

# %%
wn.synset('whale.n.01')
# Out:
# Synset('giant.n.04')
